# %%
import pandas as pd
df = pd.read_csv('C:/Users/André PC/Desktop/5/cat_acidentes.csv', sep = ';')

# %%
df
# Out:
#              data_extracao  predial1  queda_arr                 data  feridos  \
# 0      2024-07-02 17:55:28       0.0        0.0  2020-10-17 00:00:00        1
# 1      2024-07-02 17:55:28    6699.0        0.0  2019-01-01 00:00:00        1
# 2      2024-07-02 17:55:28     411.0        0.0  2019-01-01 00:00:00        1
# 3      2024-07-02 17:55:28    1500.0        0.0  2019-01-01 00:00:00        4
# 4      2024-07-02 17:55:28    8799.0        0.0  2019-01-01 00:00:00        5
# ...                    ...       ...        ...                  ...      ...
# 70577  2024-07-02 17:55:28       NaN        0.0  2024-06-29 00:00:00        1
# 70578  2024-07-02 17:55:28     444.0        0.0  2024-06-29 00:00:00        2
# 70579  2024-07-02 17:55:28    1929.0        0.0  2024-06-29 00:00:00        1
# 70580  2024-07-02 17:55:28     570.0        0.0  2024-06-29 00:00:00        1
# 70581  2024-07-02 17:55:28     110.0        0.0  2024-06-28 00:00:00        1
#
#        feridos_gr  mortes  morte_post  fatais  auto  ...     longitude  \
# 0               0       0           0       0     3  ...  0.000000e+00
# 1               0       0           0       0     3  ... -8.178406e+08
# 2               0       0           0       0     2  ... -8.267608e+08
# 3               2       0           0       0     1  ... -8.272275e+08
# 4               0       0           0       0     3  ... -8.201465e+08
# ...           ...     ...         ...     ...   ...  ...           ...
# 70577           0       0           0       0     0  ... -5.112897e+01
# 70578           0       0           0       0     2  ... -5.116973e+01
# 70579           0       0           0       0     1  ... -5.112518e+01
# 70580           0       0           0       0     1  ... -5.110156e+01
# 70581           0       1           0       1     1  ... -5.122843e+01
#
#            latitude                               log1  \
# 0      0.000000e+00                   R MARCOS MOREIRA
# 1      1.295680e+09                    AV ASSIS BRASIL
# 2      1.292030e+09                 R DR BARROS CASSAL
# 3      1.285404e+09             AV FABIO ARAUJO SANTOS
# 4      1.288712e+09                        AV IPIRANGA
# ...             ...                                ...
# 70577 -2.999380e+01  AV FRANCISCO SILVEIRA BITENCOURT
# 70578 -3.003688e+01                   R LUIZ VOELCKER
# 70579 -3.001237e+01    AV BALTAZAR DE OLIVEIRA GARCIA
# 70580 -3.002048e+01        AV ADELINO FERREIRA JARDIM
# 70581 -3.010999e+01                   ESTR VILA MARIA
#
#                               log2      tipo_acid      dia_sem  \
# 0                 R GASTON ENGLERT   ABALROAMENTO       SÁBADO
# 1                              NaN   ABALROAMENTO  TERÇA-FEIRA
# 2                              NaN   ABALROAMENTO  TERÇA-FEIRA
# 3                              NaN         CHOQUE  TERÇA-FEIRA
# 4                              NaN        COLISÃO  TERÇA-FEIRA
# ...                            ...            ...          ...
# 70577                          NaN  ATROPELAMENTO       SÁBADO
# 70578                          NaN   ABALROAMENTO       SÁBADO
# 70579                          NaN   ABALROAMENTO       SÁBADO
# 70580                          NaN   ABALROAMENTO       SÁBADO
# 70581  R CONEGO VIEIRA DA SOLEDADE   ABALROAMENTO  SEXTA-FEIRA
#
#                    hora  noite_dia  regiao  consorcio
# 0      19:00:00.0000000      NOITE   NORTE        NaN
# 1      02:45:00.0000000      NOITE   NORTE        NaN
# 2      07:36:00.0000000        DIA  CENTRO        NaN
# 3      16:50:00.0000000        DIA     SUL        NaN
# 4      19:00:00.0000000      NOITE   LESTE        NaN
# ...                 ...        ...     ...        ...
# 70577  17:00:00.0000000        DIA   NORTE        NaN
# 70578  17:00:00.0000000        DIA   LESTE        NaN
# 70579  20:50:00.0000000      NOITE   NORTE        NaN
# 70580  21:10:00.0000000      NOITE   NORTE        NaN
# 70581  12:15:00.0000000        DIA     SUL        NaN
#
# [70582 rows x 34 columns]

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.17.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.7.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting jinja2>=2.9 (from folium)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in c:\users\andré pc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from folium) (2.0.0)
# Collecting requests (from folium)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2024.6.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9->folium)
#   Downloading MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting charset-normalizer<4,>=2 (from requests->folium)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests->folium)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->folium)
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->folium)
#   Downloading certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Downloading folium-0.17.0-py2.py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    ------------------------------------- -- 102.4/108.4 kB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 108.4/108.4 kB 1.3 MB/s eta 0:00:00
# Downloading branca-0.7.2-py3-none-any.whl (25 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.3 kB ? eta -:--:--
#    ---------------------------------------  133.1/133.3 kB ? eta -:--:--
#    ---------------------------------------  133.1/133.3 kB ? eta -:--:--
#    ---------------------------------------- 133.3/133.3 kB 1.1 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ------------------------------------- -- 61.4/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB 701.1 kB/s eta 0:00:00
# Downloading xyzservices-2024.6.0-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.9 kB ? eta -:--:--
#    ---------------------------------------  81.9/83.9 kB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 83.9/83.9 kB 783.9 kB/s eta 0:00:00
# Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/163.0 kB ? eta -:--:--
#    ------------------------------------- -- 153.6/163.0 kB ? eta -:--:--
#    ------------------------------------- -- 153.6/163.0 kB ? eta -:--:--
#    ------------------------------------- -- 153.6/163.0 kB ? eta -:--:--
#    ------------------------------------- -- 153.6/163.0 kB ? eta -:--:--
#    -------------------------------------- 163.0/163.0 kB 887.9 kB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.9 kB ? eta -:--:--
#    ------------------------------------ --- 92.2/99.9 kB ? eta -:--:--
#    ---------------------------------------- 99.9/99.9 kB 1.1 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ------------------------------------ --- 61.4/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB 898.3 kB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl (17 kB)
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.4 kB ? eta -:--:--
#    ------------------------------------- -- 112.6/121.4 kB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 121.4/121.4 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: xyzservices, urllib3, MarkupSafe, idna, charset-normalizer, certifi, requests, jinja2, branca, folium
# Successfully installed MarkupSafe-2.1.5 branca-0.7.2 certifi-2024.7.4 charset-normalizer-3.3.2 folium-0.17.0 idna-3.7 jinja2-3.1.4 requests-2.32.3 urllib3-2.2.2 xyzservices-2024.6.0
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\André PC\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
df = df.dropna(subset=['latitude', 'longitude'], how='any')
df
# Out:
#              data_extracao  predial1  queda_arr                 data  feridos  \
# 0      2024-07-02 17:55:28       0.0        0.0  2020-10-17 00:00:00        1
# 1      2024-07-02 17:55:28    6699.0        0.0  2019-01-01 00:00:00        1
# 2      2024-07-02 17:55:28     411.0        0.0  2019-01-01 00:00:00        1
# 3      2024-07-02 17:55:28    1500.0        0.0  2019-01-01 00:00:00        4
# 4      2024-07-02 17:55:28    8799.0        0.0  2019-01-01 00:00:00        5
# ...                    ...       ...        ...                  ...      ...
# 70577  2024-07-02 17:55:28       NaN        0.0  2024-06-29 00:00:00        1
# 70578  2024-07-02 17:55:28     444.0        0.0  2024-06-29 00:00:00        2
# 70579  2024-07-02 17:55:28    1929.0        0.0  2024-06-29 00:00:00        1
# 70580  2024-07-02 17:55:28     570.0        0.0  2024-06-29 00:00:00        1
# 70581  2024-07-02 17:55:28     110.0        0.0  2024-06-28 00:00:00        1
#
#        feridos_gr  mortes  morte_post  fatais  auto  ...     longitude  \
# 0               0       0           0       0     3  ...  0.000000e+00
# 1               0       0           0       0     3  ... -8.178406e+08
# 2               0       0           0       0     2  ... -8.267608e+08
# 3               2       0           0       0     1  ... -8.272275e+08
# 4               0       0           0       0     3  ... -8.201465e+08
# ...           ...     ...         ...     ...   ...  ...           ...
# 70577           0       0           0       0     0  ... -5.112897e+01
# 70578           0       0           0       0     2  ... -5.116973e+01
# 70579           0       0           0       0     1  ... -5.112518e+01
# 70580           0       0           0       0     1  ... -5.110156e+01
# 70581           0       1           0       1     1  ... -5.122843e+01
#
#            latitude                               log1  \
# 0      0.000000e+00                   R MARCOS MOREIRA
# 1      1.295680e+09                    AV ASSIS BRASIL
# 2      1.292030e+09                 R DR BARROS CASSAL
# 3      1.285404e+09             AV FABIO ARAUJO SANTOS
# 4      1.288712e+09                        AV IPIRANGA
# ...             ...                                ...
# 70577 -2.999380e+01  AV FRANCISCO SILVEIRA BITENCOURT
# 70578 -3.003688e+01                   R LUIZ VOELCKER
# 70579 -3.001237e+01    AV BALTAZAR DE OLIVEIRA GARCIA
# 70580 -3.002048e+01        AV ADELINO FERREIRA JARDIM
# 70581 -3.010999e+01                   ESTR VILA MARIA
#
#                               log2      tipo_acid      dia_sem  \
# 0                 R GASTON ENGLERT   ABALROAMENTO       SÁBADO
# 1                              NaN   ABALROAMENTO  TERÇA-FEIRA
# 2                              NaN   ABALROAMENTO  TERÇA-FEIRA
# 3                              NaN         CHOQUE  TERÇA-FEIRA
# 4                              NaN        COLISÃO  TERÇA-FEIRA
# ...                            ...            ...          ...
# 70577                          NaN  ATROPELAMENTO       SÁBADO
# 70578                          NaN   ABALROAMENTO       SÁBADO
# 70579                          NaN   ABALROAMENTO       SÁBADO
# 70580                          NaN   ABALROAMENTO       SÁBADO
# 70581  R CONEGO VIEIRA DA SOLEDADE   ABALROAMENTO  SEXTA-FEIRA
#
#                    hora  noite_dia  regiao  consorcio
# 0      19:00:00.0000000      NOITE   NORTE        NaN
# 1      02:45:00.0000000      NOITE   NORTE        NaN
# 2      07:36:00.0000000        DIA  CENTRO        NaN
# 3      16:50:00.0000000        DIA     SUL        NaN
# 4      19:00:00.0000000      NOITE   LESTE        NaN
# ...                 ...        ...     ...        ...
# 70577  17:00:00.0000000        DIA   NORTE        NaN
# 70578  17:00:00.0000000        DIA   LESTE        NaN
# 70579  20:50:00.0000000      NOITE   NORTE        NaN
# 70580  21:10:00.0000000      NOITE   NORTE        NaN
# 70581  12:15:00.0000000        DIA     SUL        NaN
#
# [60632 rows x 34 columns]

# %%
import folium
from folium.plugins import HeatMap

mapa = folium.Map(location=[-30.1, -51.15], zoom_start=11)
coordenadas = list (zip(df.latitude, df.longitude))
mapa_calor = HeatMap(coordenadas, radius=9, blur=10)
mapa.add_child(mapa_calor)

mapa

# %%
from folium.plugins import MarkerCluster

mapa = folium.Map(location=[-30.1, -51.15], zoom_start=11)
mapa_cluster = MarkerCluster(coordenadas)
mapa.add_child(mapa_cluster)

mapa

# %%
df.data
# Out:
# 0        2020-10-17 00:00:00
# 1        2019-01-01 00:00:00
# 2        2019-01-01 00:00:00
# 3        2019-01-01 00:00:00
# 4        2019-01-01 00:00:00
#                 ...
# 70577    2024-06-29 00:00:00
# 70578    2024-06-29 00:00:00
# 70579    2024-06-29 00:00:00
# 70580    2024-06-29 00:00:00
# 70581    2024-06-28 00:00:00
# Name: data, Length: 60632, dtype: object

# %%
df['data'] = pd.to_datetime(df['data'], errors='coerce')
df_ano = df['data'].dt.year.value_counts()
df_ano
# Out:
# C:\Users\André PC\AppData\Local\Temp\ipykernel_15320\3729456432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['data'] = pd.to_datetime(df['data'], errors='coerce')
# data
# 2023    14566
# 2022    13326
# 2019    12444
# 2021    11700
# 2024     5699
# 2020     2896
# 2202        1
# Name: count, dtype: int64

# %%
df_ano = df_ano.drop(2202)
df_ano
# Out:
# data
# 2023    14566
# 2022    13326
# 2019    12444
# 2021    11700
# 2024     5699
# 2020     2896
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(df_ano.index, df_ano.values)
plt.show()

# %%
df_ano/df_ano.max()
# Out:
# data
# 2023    1.000000
# 2022    0.914870
# 2019    0.854318
# 2021    0.803240
# 2024    0.391254
# 2020    0.198819
# Name: count, dtype: float64

# %%
gradiente = df_ano/df_ano.max()
cores = plt.cm.Blues(gradiente)
plt.bar(df_ano.index, df_ano.values, color = cores)
plt.show()
